# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
np.random.seed(0)

x = np.random.rand(100, 5)   # 100 random points between 0 and 10
y = 2 + 3 * x + np.random.rand(100, 1)  # y = 2 + 3x + noise

# %%
regression_model = LinearRegression()
regression_model.fit(x, y)
y_pred = regression_model.predict(x)

# %%
rmse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)
print(f"RMSE: {rmse:.2f}, R^2: {r2:.2f}")
# Out:
# RMSE: 0.09, R^2: 0.89

# %%
print('Slope:' ,regression_model.coef_)
print('Intercept:', regression_model.intercept_)
print('Root mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [[ 3.01677732e+00 -1.53502696e-01  6.18307786e-03  1.83093094e-02
#   -1.34337455e-03]
#  [ 1.67773199e-02  2.84649730e+00  6.18307786e-03  1.83093094e-02
#   -1.34337455e-03]
#  [ 1.67773199e-02 -1.53502696e-01  3.00618308e+00  1.83093094e-02
#   -1.34337455e-03]
#  [ 1.67773199e-02 -1.53502696e-01  6.18307786e-03  3.01830931e+00
#   -1.34337455e-03]
#  [ 1.67773199e-02 -1.53502696e-01  6.18307786e-03  1.83093094e-02
#    2.99865663e+00]]
# Intercept: [2.56372509 2.56372509 2.56372509 2.56372509 2.56372509]
# Root mean squared error:  0.08884909078234086
# R2 score:  0.8927345807059404

# %%
# data points
plt.scatter(x, y, s=10)
plt.xlabel('x')
plt.ylabel('y')
# Hiển thị dữ liệu
plt.plot(x, y_pred, color='r')
plt.show()

# %%
import pandas as pd
dataset = pd.read_csv('Salaries.csv')
dataset.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800
